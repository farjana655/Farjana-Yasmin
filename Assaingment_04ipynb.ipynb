# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/Garment_Job_Risk_bulk_dataset.csv")
df
# Out:
#                   Name    Garment_Name  Experience_Years    Job_Role  \
# 0        Taslima Akter  Pallmall Group                38   Packaging
# 1        Rasel Hossain  Pallmall Group                28   Packaging
# 2          Abdul Latif  Pallmall Group                14  Supervisor
# 3        Nazia Sultana  Pallmall Group                 7      Sewing
# 4        Nazia Sultana  Pallmall Group                20   Packaging
# ...                ...             ...               ...         ...
# 2495     Shamina Begum  Pallmall Group                18      Dyeing
# 2496       Fariha Khan  Pallmall Group                30      Dyeing
# 2497       Fariha Khan  Pallmall Group                18   Packaging
# 2498  Mushfiqur Rahman  Pallmall Group                18     Cutting
# 2499  Mushfiqur Rahman  Pallmall Group                21   Packaging
#
#       Working_Hours_Per_Week Exposure_To_Chemicals Machine_Use  \
# 0                         41                Medium       Light
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Garment_Name', 'Experience_Years', 'Job_Role',
#        'Working_Hours_Per_Week', 'Exposure_To_Chemicals', 'Machine_Use',
#        'Workstation_Ergonomics', 'Injury_History', 'Health_Condition',
#        'Safety_Training', 'Shift_Type', 'Task_Rotation_Frequency', 'Job_Risk'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Name                     2500 non-null   object
#  1   Garment_Name             2500 non-null   object
#  2   Experience_Years         2500 non-null   int64
#  3   Job_Role                 2500 non-null   object
#  4   Working_Hours_Per_Week   2500 non-null   int64
#  5   Exposure_To_Chemicals    1276 non-null   object
#  6   Machine_Use              2046 non-null   object
#  7   Workstation_Ergonomics   2500 non-null   object
#  8   Injury_History           2500 non-null   int64
#  9   Health_Condition         2500 non-null   object
#  10  Safety_Training          2062 non-null   object
#  11  Shift_Type               2500 non-null   object
#  12  Task_Rotation_Frequency  2500 non-null   object
#  13  Job_Risk                 2500 non-null   object
# ...

# %%
df.shape
# Out:
# (2500, 14)

# %%
df.describe()
# Out:
#        Experience_Years  Working_Hours_Per_Week  Injury_History
# count       2500.000000             2500.000000     2500.000000
# mean          20.248800               48.027600        0.579200
# std           11.832214               11.702548        0.761025
# min            0.000000               28.000000        0.000000
# 25%           10.000000               38.000000        0.000000
# 50%           21.000000               48.000000        0.000000
# 75%           31.000000               58.000000        1.000000
# max           40.000000               68.000000        6.000000

# %%
df.describe(include="object")
# Out:
#                  Name    Garment_Name Job_Role Exposure_To_Chemicals  \
# count            2500            2500     2500                  2500
# unique             10               1        7                     3
# top     Shamina Begum  Pallmall Group   Sewing                   Low
# freq              266            2500      738                  1858
#
#        Machine_Use Workstation_Ergonomics Health_Condition Safety_Training  \
# count         2500                   2500             2500            2500
# unique           2                      3                3               2
# top          Light                Average          Healthy           Basic
# freq          1857                   1300             1797            1823
#
#        Shift_Type Task_Rotation_Frequency Job_Risk
# count        2500                    2500     2500
# unique          3                       3        3
# top           Day              Occasional      Low
# ...

# %%
df.isnull().sum()
# Out:
# Name                          0
# Garment_Name                  0
# Experience_Years              0
# Job_Role                      0
# Working_Hours_Per_Week        0
# Exposure_To_Chemicals      1224
# Machine_Use                 454
# Workstation_Ergonomics        0
# Injury_History                0
# Health_Condition              0
# Safety_Training             438
# Shift_Type                    0
# Task_Rotation_Frequency       0
# Job_Risk                      0
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# Name                        0.00
# Garment_Name                0.00
# Experience_Years            0.00
# Job_Role                    0.00
# Working_Hours_Per_Week      0.00
# Exposure_To_Chemicals      48.96
# Machine_Use                18.16
# Workstation_Ergonomics      0.00
# Injury_History              0.00
# Health_Condition            0.00
# Safety_Training            17.52
# Shift_Type                  0.00
# Task_Rotation_Frequency     0.00
# Job_Risk                    0.00
# dtype: float64

# %% [markdown]
# # **Missing Values Handling**
#
# এই ডেটাসেটের তিনটা কলামে নাল ভ্যালু আছে
#
#
# * Exposure_To_Chemicals এই কলামের ভ্যালু ক্যাটাগরিক্যাল ভ্যালু তাই mode দিয়ে ফিল করেছি ।
# * Machine_Use এই কলামের ভ্যালু ক্যাটাগরিক্যাল ভ্যালু তাই mode দিয়ে ফিল করেছি।
#
#
# *  এই কলামের ভ্যালু ক্যাটাগরিক্যাল ভ্যালু তাই mode দিয়ে ফিল করেছি

# %%
df['Exposure_To_Chemicals'].unique()
# Out:
# array(['Medium', 'Low', 'High', nan], dtype=object)

# %%
df['Exposure_To_Chemicals']=df['Exposure_To_Chemicals'].fillna(df['Exposure_To_Chemicals'].mode()[0])

# %%
df['Machine_Use'].unique()
# Out:
# array(['Light', nan, 'Heavy'], dtype=object)

# %%
df['Machine_Use']=df['Machine_Use'].fillna(df['Machine_Use'].mode()[0])

# %%
df['Safety_Training'].unique()
# Out:
# array(['Basic', nan, 'Advanced'], dtype=object)

# %%
df['Safety_Training']=df['Safety_Training'].fillna(df['Safety_Training'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Name                       0
# Garment_Name               0
# Experience_Years           0
# Job_Role                   0
# Working_Hours_Per_Week     0
# Exposure_To_Chemicals      0
# Machine_Use                0
# Workstation_Ergonomics     0
# Injury_History             0
# Health_Condition           0
# Safety_Training            0
# Shift_Type                 0
# Task_Rotation_Frequency    0
# Job_Risk                   0
# dtype: int64

# %% [markdown]
# # **duplicated check**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# # **Wrong Format Fix**

# %%
df.dtypes
# Out:
# Name                       object
# Garment_Name               object
# Experience_Years            int64
# Job_Role                   object
# Working_Hours_Per_Week      int64
# Exposure_To_Chemicals      object
# Machine_Use                object
# Workstation_Ergonomics     object
# Injury_History              int64
# Health_Condition           object
# Safety_Training            object
# Shift_Type                 object
# Task_Rotation_Frequency    object
# Job_Risk                   object
# dtype: object

# %% [markdown]
# # **Inconsistent Labels check**

# %%
df['Garment_Name'].unique()
# Out:
# array(['Pallmall Group'], dtype=object)

# %%
df['Job_Role'].unique()
# Out:
# array(['Packaging', 'Supervisor', 'Sewing', 'Ironing', 'Cutting',
#        'Dyeing', 'Machine_Maintenance'], dtype=object)

# %%
df['Exposure_To_Chemicals'].unique()
# Out:
# array(['Medium', 'Low', 'High'], dtype=object)

# %%
df['Machine_Use'].unique()
# Out:
# array(['Light', 'Heavy'], dtype=object)

# %%
df['Workstation_Ergonomics'].unique()
# Out:
# array(['Average', 'Good', 'Poor'], dtype=object)

# %%
df['Health_Condition'].unique()
# Out:
# array(['Healthy', 'Minor_Chronic', 'Serious_Chronic'], dtype=object)

# %%
df['Safety_Training'].unique()
# Out:
# array(['Basic', 'Advanced'], dtype=object)

# %%
df['Shift_Type'].unique()
# Out:
# array(['Day', 'Night', 'Evening'], dtype=object)

# %%
df['Task_Rotation_Frequency'].unique()
# Out:
# array(['Occasional', 'Frequent', 'Rare'], dtype=object)

# %%
df['Job_Risk'].unique()
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %% [markdown]
# # **Outlier Detection **

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.title(" Experience_Years")
sns.boxplot(df.Experience_Years)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(df.Working_Hours_Per_Week)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(df.Injury_History)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
numerical_col=df.select_dtypes(include=["int64"]).columns
for col in numerical_col:
  Q1=df[col].quantile(.25)
  Q3=df[col].quantile(.75)
  IQR=Q3 -Q1
  lower=Q1 - 1.5 * IQR
  upper =Q3 + 1.5 * IQR
  outliers=df[(df[col] < lower ) | (df[col] > upper)]
  print(f"{col} : {len(outliers)}")
# Out:
# Experience_Years : 0
# Working_Hours_Per_Week : 0
# Injury_History : 54

# %% [markdown]
# # **Noisy Data Filtering**

# %%
df=df[df['Experience_Years'] >= 0]
df=df[df['Working_Hours_Per_Week'] >= 0]
df=df[df['Injury_History'] >=0]

# %% [markdown]
# # Data Type Consistency Check

# %%
df.dtypes
# Out:
# Name                       object
# Garment_Name               object
# Experience_Years            int64
# Job_Role                   object
# Working_Hours_Per_Week      int64
# Exposure_To_Chemicals      object
# Machine_Use                object
# Workstation_Ergonomics     object
# Injury_History              int64
# Health_Condition           object
# Safety_Training            object
# Shift_Type                 object
# Task_Rotation_Frequency    object
# Job_Risk                   object
# dtype: object

# %% [markdown]
# # **Schema Validation**

# %%
required_cols=['Name', 'Garment_Name', 'Experience_Years', 'Job_Role',
       'Working_Hours_Per_Week', 'Exposure_To_Chemicals', 'Machine_Use',
       'Workstation_Ergonomics', 'Injury_History', 'Health_Condition',
       'Safety_Training', 'Shift_Type', 'Task_Rotation_Frequency', 'Job_Risk']
missing=(set(required_cols)
            -set(df.columns)
)
extra=(
    set(df.columns)
    - set(required_cols)
)
print(f"Missing : {missing}")
print(f"Extra : {extra}")
# Out:
# Missing : set()
# Extra : set()

# %%
df.describe()
# Out:
#        Experience_Years  Working_Hours_Per_Week  Injury_History
# count       2500.000000             2500.000000     2500.000000
# mean          20.248800               48.027600        0.579200
# std           11.832214               11.702548        0.761025
# min            0.000000               28.000000        0.000000
# 25%           10.000000               38.000000        0.000000
# 50%           21.000000               48.000000        0.000000
# 75%           31.000000               58.000000        1.000000
# max           40.000000               68.000000        6.000000

# %% [markdown]
# ## ** Data Range Validation**

# %%
df=df[df['Experience_Years'] >= 0]
df=df[df['Injury_History']>= 0]
df=df[df['Working_Hours_Per_Week'] >=0]

# %% [markdown]
# # Imbalanced Data Check

# %%
df['Job_Risk'].value_counts()
df['Job_Risk'].value_counts(normalize=True) * 100
# Out:
# Job_Risk
# Low       42.0
# Medium    36.0
# High      22.0
# Name: proportion, dtype: float64

# %% [markdown]
# # **Save the data set**

# %%
df.to_csv("cleandataset.csv",index=False)
